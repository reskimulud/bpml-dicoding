# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import numpy as np
from keras.models import Sequential
from keras.layers import Dense

# %%
df = pd.read_csv('citrus.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      10000 non-null  object
#  1   diameter  10000 non-null  float64
#  2   weight    10000 non-null  float64
#  3   red       10000 non-null  int64
#  4   green     10000 non-null  int64
#  5   blue      10000 non-null  int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 468.9+ KB

# %%
df.head(1000)
# Out:
#        name  diameter  weight  red  green  blue
# 0    orange      2.96   86.76  172     85     2
# 1    orange      3.91   88.05  166     78     3
# 2    orange      4.42   95.17  156     81     2
# 3    orange      4.47   95.60  163     81     4
# 4    orange      4.48   95.76  161     72     9
# ..      ...       ...     ...  ...    ...   ...
# 995  orange      7.43  137.10  158     78     3
# 996  orange      7.44  137.12  164     97     2
# 997  orange      7.44  137.18  140     88     2
# 998  orange      7.44  137.23  148     85     2
# 999  orange      7.44  137.24  166     83     7
#
# [1000 rows x 6 columns]

# %%
df.name[df.name == 'orange'] = 0
df.name[df.name == 'grapefruit'] = 1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dataset = df.values
print(dataset)
# Out:
# [[0 2.96 86.76 172 85 2]
#  [0 3.91 88.05 166 78 3]
#  [0 4.42 95.17 156 81 2]
#  ...
#  [1 15.59 256.5 168 82 20]
#  [1 15.92 260.14 142 72 11]
#  [1 16.45 261.51 152 74 2]]

# %%
# memberikan atribut dan label

x = dataset[:, 1:6]  # atribut
y = dataset[:, 0]    # label

print(x)
print()
print(y)
# Out:
# [[2.96 86.76 172 85 2]
#  [3.91 88.05 166 78 3]
#  [4.42 95.17 156 81 2]
#  ...
#  [15.59 256.5 168 82 20]
#  [15.92 260.14 142 72 11]
#  [16.45 261.51 152 74 2]]
#
# [0 0 0 ... 1 1 1]

# %%
# Normalisasi
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(x)
X_scale
# Out:
# array([[0.        , 0.        , 0.74025974, 0.63529412, 0.        ],
#        [0.07042254, 0.00738197, 0.66233766, 0.55294118, 0.01851852],
#        [0.10822832, 0.04812589, 0.53246753, 0.58823529, 0.        ],
#        ...,
#        [0.93624907, 0.97133047, 0.68831169, 0.6       , 0.33333333],
#        [0.96071164, 0.99216023, 0.35064935, 0.48235294, 0.16666667],
#        [1.        , 1.        , 0.48051948, 0.50588235, 0.        ]])

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, y, test_size=0.3)

# %%
Y_train = Y_train.astype(np.float32)
Y_test = Y_test.astype(np.float32)

# %%
model = Sequential([Dense(32, activation='relu', input_shape=(5,)),
                    Dense(32, activation='relu'),
                    Dense(1, activation='sigmoid')])

# %%
model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, Y_train, epochs=100)
# Out:
# Epoch 1/100
# 219/219 [==============================] - 15s 1ms/step - loss: 0.7042 - accuracy: 0.5305
# Epoch 2/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6415 - accuracy: 0.8505
# Epoch 3/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.5913 - accuracy: 0.8851
# Epoch 4/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.5231 - accuracy: 0.9003
# Epoch 5/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4342 - accuracy: 0.9216
# Epoch 6/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3520 - accuracy: 0.9201
# Epoch 7/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.2869 - accuracy: 0.9281
# Epoch 8/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.2445 - accuracy: 0.9272
# Epoch 9/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.2249 - accuracy: 0.9250
# Epoch 10/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.2042 - accuracy: 0.9296
# Epoch 11/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1950 - accuracy: 0.9277
# Epoch 12/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.2006 - accuracy: 0.9198
# Epoch 13/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1841 - accuracy: 0.9283
# Epoch 14/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1866 - accuracy: 0.9288
# Epoch 15/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1825 - accuracy: 0.9291
# Epoch 16/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1872 - accuracy: 0.9265
# Epoch 17/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1828 - accuracy: 0.9269
# Epoch 18/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1785 - accuracy: 0.9332
# Epoch 19/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1690 - accuracy: 0.9328
# Epoch 20/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1753 - accuracy: 0.9290
# Epoch 21/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1824 - accuracy: 0.9269
# Epoch 22/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1754 - accuracy: 0.9284
# Epoch 23/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1709 - accuracy: 0.9326
# Epoch 24/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1851 - accuracy: 0.9231
# Epoch 25/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1623 - accuracy: 0.9336
# Epoch 26/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1820 - accuracy: 0.9234
# Epoch 27/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1719 - accuracy: 0.9289
# Epoch 28/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1778 - accuracy: 0.9310
# Epoch 29/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1711 - accuracy: 0.9337
# Epoch 30/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1751 - accuracy: 0.9304
# Epoch 31/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1736 - accuracy: 0.9276
# Epoch 32/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1703 - accuracy: 0.9322
# Epoch 33/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1813 - accuracy: 0.9237
# Epoch 34/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1785 - accuracy: 0.9308
# Epoch 35/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1794 - accuracy: 0.9285
# Epoch 36/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1726 - accuracy: 0.9304
# Epoch 37/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1749 - accuracy: 0.9310
# Epoch 38/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1761 - accuracy: 0.9297
# Epoch 39/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1789 - accuracy: 0.9254
# Epoch 40/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1869 - accuracy: 0.9253
# Epoch 41/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1754 - accuracy: 0.9289
# Epoch 42/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1692 - accuracy: 0.9374
# Epoch 43/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1704 - accuracy: 0.9326
# Epoch 44/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1597 - accuracy: 0.9369
# Epoch 45/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1680 - accuracy: 0.9327
# Epoch 46/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1859 - accuracy: 0.9275
# Epoch 47/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1693 - accuracy: 0.9334
# Epoch 48/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1760 - accuracy: 0.9300
# Epoch 49/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1828 - accuracy: 0.9290
# Epoch 50/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1755 - accuracy: 0.9294
# Epoch 51/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1700 - accuracy: 0.9280
# Epoch 52/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1683 - accuracy: 0.9362
# Epoch 53/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1793 - accuracy: 0.9299
# Epoch 54/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1717 - accuracy: 0.9297
# Epoch 55/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1833 - accuracy: 0.9293
# Epoch 56/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1755 - accuracy: 0.9291
# Epoch 57/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1817 - accuracy: 0.9299
# Epoch 58/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1880 - accuracy: 0.9216
# Epoch 59/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1681 - accuracy: 0.9357
# Epoch 60/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1795 - accuracy: 0.9253
# Epoch 61/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1772 - accuracy: 0.9281
# Epoch 62/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1864 - accuracy: 0.9236
# Epoch 63/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1698 - accuracy: 0.9304
# Epoch 64/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1789 - accuracy: 0.9296
# Epoch 65/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1819 - accuracy: 0.9264
# Epoch 66/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1812 - accuracy: 0.9278
# Epoch 67/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1638 - accuracy: 0.9319
# Epoch 68/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1769 - accuracy: 0.9272
# Epoch 69/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1771 - accuracy: 0.9291
# Epoch 70/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1702 - accuracy: 0.9344
# Epoch 71/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1730 - accuracy: 0.9343
# Epoch 72/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1861 - accuracy: 0.9254
# Epoch 73/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1787 - accuracy: 0.9271
# Epoch 74/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1744 - accuracy: 0.9305
# Epoch 75/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1757 - accuracy: 0.9282
# Epoch 76/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1830 - accuracy: 0.9266
# Epoch 77/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1702 - accuracy: 0.9315
# Epoch 78/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1787 - accuracy: 0.9305
# Epoch 79/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1694 - accuracy: 0.9316
# Epoch 80/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1821 - accuracy: 0.9302
# Epoch 81/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1794 - accuracy: 0.9288
# Epoch 82/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1875 - accuracy: 0.9250
# Epoch 83/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1780 - accuracy: 0.9257
# Epoch 84/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1679 - accuracy: 0.9344
# Epoch 85/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1795 - accuracy: 0.9269
# Epoch 86/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1744 - accuracy: 0.9347
# Epoch 87/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1728 - accuracy: 0.9281
# Epoch 88/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1768 - accuracy: 0.9299
# Epoch 89/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1843 - accuracy: 0.9272
# Epoch 90/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1783 - accuracy: 0.9275
# Epoch 91/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1780 - accuracy: 0.9286
# Epoch 92/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1745 - accuracy: 0.9307
# Epoch 93/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1762 - accuracy: 0.9320
# Epoch 94/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1690 - accuracy: 0.9302
# Epoch 95/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1784 - accuracy: 0.9278
# Epoch 96/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1784 - accuracy: 0.9284
# Epoch 97/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1679 - accuracy: 0.9307
# Epoch 98/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1765 - accuracy: 0.9266
# Epoch 99/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1743 - accuracy: 0.9297
# Epoch 100/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1797 - accuracy: 0.9307

# %%
model.evaluate(X_test, Y_test)
# Out:
# 94/94 [==============================] - 1s 937us/step - loss: 0.1867 - accuracy: 0.9190
# [0.1867029368877411, 0.9190000295639038]
